# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

# %%
# Data for plotting
#t = np.arange(np.Infinity, np.NINF, .001)
t = np.arange(1., 10., .001)
g = t ** 2 

fig, ax = plt.subplots()
ax.plot(t, g)

ax.grid()

fig.savefig("test.png")
plt.show()

# %%
# Data for plotting

#t = np.arange(np.Infinity, np.NINF, .001)

#Infinity
#Negative Infinity

t = np.arange(1., 10., .001)
g = 1 / t 

fig, ax = plt.subplots()
ax.plot(t, g)

ax.grid()

fig.savefig("test.png")
plt.show()

# %%
# Data for plotting

#t = np.arange(np.Infinity, np.NINF, .001)

#Infinity
#Negative Infinity

t = np.arange(1., 10., .001)
g = np.sqrt(t) 

fig, ax = plt.subplots()
ax.plot(t, g)

ax.grid()

fig.savefig("test.png")
plt.show()

# %%
# Data for plotting

#t = np.arange(np.Infinity, np.NINF, .001)

#Infinity
#Negative Infinity

t = np.arange(-11, 4, 1)

g = np.sqrt(4 - t) 

fig, ax = plt.subplots()
ax.plot(t, g)

ax.grid()

plt.show()

# %%
# Data for plotting
t = np.arange(0.0, 2.0, .001)
s =  np.sin(2 * np.pi * t)
fig, ax = plt.subplots()

ax.plot(t, s)
ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
# Data for plotting
t = np.arange(0.0, 2.0, .001)
c = np.cos(2 * np.pi * t)
fig, ax = plt.subplots()
ax.plot(t, c)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
N = 8
y = np.zeros(N)
x1 = np.linspace(0, 10, N, endpoint=True)
x2 = np.linspace(0, 10, N, endpoint=False)
plt.plot(x1, y, 'o')
plt.plot(x2, y + 0.5, 'o')
plt.ylim([-0.5, 1])
plt.show()

# %%
t = np.arange(-6, 4, 1)

fig, ax = plt.subplots()
ax.plot(t, t ** 2, 'o')
ax.grid()
plt.show()

# %%
t = np.arange(-6, 6, 1)

fig, ax = plt.subplots()

ax.plot(t, np.absolute(t) , 'o')
ax.grid()
plt.show()

# %%
x = np.linspace(start=-10, stop=10, num=101)
xx = x + 1j * x[:, np.newaxis]
plt.imshow(np.abs(xx), extent=[-10, 10, -10, 10], cmap='gray')
plt.show()

# %%
# Data for plotting

#t = np.arange(np.Infinity, np.NINF, .001)

#Infinity
#Negative Infinity

t = np.arange(-1., 1., .001)

a = np.sqrt(1 - t ** 2)
n = -np.sqrt(1 - t ** 2)

fig, ax = plt.subplots()
fig, ax2 = plt.subplots()
ax.plot(t, a)
ax2.plot(t, n)

ax.grid()
ax2.grid()
plt.show()

# %%
import numpy as np
ar = np.arange(10) # just as an example array

fig, ax = plt.subplots()
ax.plot(ar, np.zeros_like(ar) + 2)
ax.grid()

plt.show()

# %%
t1 = np.arange(-6, 1, 1)
t2 = np.arange(0., 1., .001)
t3 = np.arange(1., 6., .001)
fig, ax = plt.subplots()

ax.plot(t1, -t1 )
ax.plot(t2, t2 ** 2 )
ax.plot(t3, np.zeros_like(t3) + 1 , 'o')

ax.grid()
plt.show()

# %%
t1 = np.arange(1, 1, 1)
t2 = np.arange(0., 1., .001)
t3 = np.arange(1., 6., .001)
fig, ax = plt.subplots()

ax.plot(t1, t1 )
ax.plot(t2, t2 - 1 )


ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(14)
y = np.sin(x / 2)

plt.step(x, y + 2, label='pre (default)')
plt.plot(x, y + 2, 'C0o', alpha=0.5)

plt.step(x, y + 1, where='mid', label='mid')
plt.plot(x, y + 1, 'C1o', alpha=0.5)

plt.step(x, y, where='post', label='post')
plt.plot(x, y, 'C2o', alpha=0.5)

plt.legend(title='Parameter where:')
plt.show()

# %%
t1 = np.arange(-2., 2., .001)

fig, ax = plt.subplots()

ax.plot(t1, t1 ** 2 + 2 )
ax.plot(t1, t1 ** 2 + 1 )
ax.plot(t1, t1 ** 2 )
ax.plot(t1, t1 ** 2 - 1 )
ax.plot(t1, t1 ** 2 - 2 )

plt.axhline(linewidth=4, color='b')
ax.grid()
plt.show()

# %%
t1 = np.arange(-10., 10., .001)

fig, ax = plt.subplots()

ax.plot(t1, t1 ** 2 )
ax.plot(t1, (t1 ** 2 ) + 3 )
ax.plot(t1, (t1 ** 2 ) - 3 )
ax.plot(t1, (t1 + 3)** 2 )
ax.plot(t1, (t1 - 3)** 2 )
plt.axhline(linewidth=4, color='b')
ax.grid()
plt.show()
